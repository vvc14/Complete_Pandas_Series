# %%
import pandas as pd

# %%
df=pd.read_excel("Company_Data.xlsx",sheet_name="Add23-24",header=[2])
df
# Out:
# C:\Users\vvc14\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\vvc14\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\vvc14\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#      Unnamed: 0                  Sl.No. Construction Equipment  \
# 0           NaN  Construction Equipment                    NaN
# 1           NaN                       1               Vibrator
# 2           NaN                       2               Vibrator
# 3           NaN                       3        Welding Machine
# ...

# %%
df1=df.pivot_table(index="Location of the Asset",aggfunc={
    'Capital Cost':'sum',
    'Depreciation':'sum'
})
df1
# Out:
#                            Capital Cost     Depreciation
# Location of the Asset
# Brahmani  HL Bridge              820550             4623
# Brahmani Bridge              32314107.9   2283388.870384
# ECR                      5317003.849492    452012.393438
# FOB-TS                         491675.3     78655.439269
# Foxconn                     22738746.66   1366646.098404
# Hadua                   67981519.248814   5116190.824498
# Head Office                 26124487.92   1728413.768056
# KDP-IV                 109903128.611356  10797046.343429
# KDP-V                        3877192.33    585396.119671
# Kaiga                           6102541           678060
# Lower Tapi                    462237.28      4998.531163
# MRPL Terminal Project             88235     15256.353425
# Manufacturing Unit           8526156.04   1168415.792824
# Pedasankarlapudi                 545904     32443.782014
# Polavaram                         55590      5700.640274
# ...

# %%
df2=df1['YTPS'][0]
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YTPS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df2=df1['YTPS'][0]
#       2 df2
#
# ...
